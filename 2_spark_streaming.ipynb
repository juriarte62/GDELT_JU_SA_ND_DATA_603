# %%
###### set up libraries ######
# set up spark session
from pyspark.sql import SparkSession
# set up spark schema
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, BooleanType, TimestampType, DateType, FloatType, DoubleType, ArrayType
# this is to convert the string to datetime
from pyspark.sql import functions as F
# set up date filtering step
from pyspark.sql.functions import current_date, date_sub, col, to_date, col, instr, when, lower
# from pyspark.sql.functions import col
# from pyspark.sql.functions import instr

# extras
import requests
import json
import pandas as pd
import numpy as np
# import os # installed down below

# %%
###### IMPORTANT MESSAGE ######
# This is something I had to do on the last assignment 
# my JAVA_HOME and HADOOP_HOME is all messed up, so I have to mnaually set up the 
# the home variables here and everything works :)
import sys
# sys.stdout.reconfigure(encoding='utf-8') # to avoid unicode encoding errors --pray it works (Johnny boy)
import os
# os.environ['JAVA_HOME'] = r'C:\Program Files\Eclipse Adoptium\jdk-17' # have to manually change my java home path
# os.environ['JAVA_HOME'] = r'/c/Program Files/Eclipse Adoptium/jdk-17.0.17.10-hotspot' # have to manually change my java home path
os.environ['JAVA_HOME'] = r'C:\Program Files\Eclipse Adoptium\jdk-17.0.17.10-hotspot'
# I had to mess around with my original hadoop settings -JU
os.environ['HADOOP_HOME'] = r'C:\hadoop'
# Read message future johnny about why we have to use ; instead of : in path
## for whatever reason, some big brain at microsoft that you should put a ; in front of the C: directory
## which makes total sense, and by that I mean it makes no sense at all!
## The stackoverflow says this work and I'm sticking to it
os.environ['PATH'] += r';C:\hadoop\bin'

# %% [markdown]
# # Step 0: Path setups
# * Some paths might be pre-set up with the data download notebook

# %%
input_dir = r'C:\Users\jonat\Documents\UMBC\FALL_2025\Final_Project_UMBC_BIG_DATA\DATA\stream_in'
output_dir = r'C:\Users\jonat\Documents\UMBC\FALL_2025\Final_Project_UMBC_BIG_DATA\DATA\stream_out'
checkpoint_dir = r'C:\Users\jonat\Documents\UMBC\FALL_2025\Final_Project_UMBC_BIG_DATA\DATA\checkpoints\tech_sentiment'

print('Input dir:', input_dir)
print('Output dir:', output_dir)
print('Checkpoint dir:', checkpoint_dir)

os.makedirs(output_dir, exist_ok=True)
os.makedirs(os.path.dirname(checkpoint_dir), exist_ok=True)
# Out:
# Input dir: C:\Users\jonat\Documents\UMBC\FALL_2025\Final_Project_UMBC_BIG_DATA\DATA\stream_in
# Output dir: C:\Users\jonat\Documents\UMBC\FALL_2025\Final_Project_UMBC_BIG_DATA\DATA\stream_out
# Checkpoint dir: C:\Users\jonat\Documents\UMBC\FALL_2025\Final_Project_UMBC_BIG_DATA\DATA\checkpoints\tech_sentiment

# %% [markdown]
# # Step 1: Create Spark Session & schema
# * Just like in the Chicago assignment
#
# Here is the dataformat code book that tells me all the columns
# [Data Event Cookbook](http://data.gdeltproject.org/documentation/GDELT-Event_Codebook-V2.0.pdf)

# %%
# create spark session
spark = SparkSession.builder.appName('GDELT_May2018_Streaming').getOrCreate()

# %%
gkg_schema = StructType([
    StructField('GKGRECORDID',              StringType(), True),
    StructField('DATE',                     StringType(), True),
    StructField('SourceCollectionIdentifier', StringType(), True),
    StructField('SourceCommonName',         StringType(), True),
    StructField('DocumentIdentifier',       StringType(), True),
    StructField('V1Counts',                 StringType(), True),
    StructField('V2Counts',                 StringType(), True),
    StructField('V1Themes',                 StringType(), True),
    StructField('V2Themes',                 StringType(), True),
    StructField('V1Locations',              StringType(), True),
    StructField('V2Locations',              StringType(), True),
    StructField('V1Persons',                StringType(), True),
    StructField('V2Persons',                StringType(), True),
    StructField('V1Organizations',          StringType(), True),
    StructField('V2Organizations',          StringType(), True),
    StructField('V1Tone',                   StringType(), True),
    StructField('V2Tone',                   StringType(), True),
    StructField('Dates',                    StringType(), True),
    StructField('GCAM',                     StringType(), True),
    StructField('SharingImage',             StringType(), True),
    StructField('RelatedImages',            StringType(), True),
    StructField('SocialImageEmbeds',        StringType(), True),
    StructField('SocialVideoEmbeds',        StringType(), True),
    StructField('Quotations',               StringType(), True),
    StructField('AllNames',                 StringType(), True),
    StructField('Amounts',                  StringType(), True),
    StructField('TranslationInfo',          StringType(), True),
    StructField('Extras',                   StringType(), True),
])

# %% [markdown]
# # Step 2: Streaming unzipped source files

# %%
# process 1 new file per micro-batch
# stream_df = spark.readStream.format('text').option('maxFilesPerTrigger', 1).load(input_dir)

# # 'value' column contains one line of GKG per row
# gkg_stream = stream_df.select(col('value').alias('gkg_raw'))

gkg_stream = spark.readStream \
    .format('csv') \
    .schema(gkg_schema) \
    .option('sep', '\t') \
    .option('header', 'false') \
    .option('maxFilesPerTrigger', 1) \
    .load(input_dir)

gkg_stream.printSchema()
# Out:
# root
#  |-- GKGRECORDID: string (nullable = true)
#  |-- DATE: string (nullable = true)
#  |-- SourceCollectionIdentifier: string (nullable = true)
#  |-- SourceCommonName: string (nullable = true)
#  |-- DocumentIdentifier: string (nullable = true)
#  |-- V1Counts: string (nullable = true)
#  |-- V2Counts: string (nullable = true)
#  |-- V1Themes: string (nullable = true)
#  |-- V2Themes: string (nullable = true)
#  |-- V1Locations: string (nullable = true)
#  |-- V2Locations: string (nullable = true)
#  |-- V1Persons: string (nullable = true)
#  |-- V2Persons: string (nullable = true)
#  |-- V1Organizations: string (nullable = true)
#  |-- V2Organizations: string (nullable = true)
#  |-- V1Tone: string (nullable = true)
#  |-- V2Tone: string (nullable = true)
#  |-- Dates: string (nullable = true)
#  |-- GCAM: string (nullable = true)
#  |-- SharingImage: string (nullable = true)
#  |-- RelatedImages: string (nullable = true)
#  |-- SocialImageEmbeds: string (nullable = true)
#  |-- SocialVideoEmbeds: string (nullable = true)
#  |-- Quotations: string (nullable = true)
#  |-- AllNames: string (nullable = true)
#  |-- Amounts: string (nullable = true)
#  |-- TranslationInfo: string (nullable = true)
#  |-- Extras: string (nullable = true)

# %% [markdown]
# # Step 3: filter for tech related topics

# %%
# filter for tech related stuff
# Simple check (update later): keep rows mentioning some tech-related keywords in the line
# tech_stream = gkg_stream.filter(
#     (instr(col('gkg_raw'), 'TECHNOLOGY') > 0) |
#     (instr(col('gkg_raw'), 'SCIENCE_TECHNOLOGY') > 0) |
#     (instr(col('gkg_raw'), 'INTERNET') > 0) |
#     (instr(col('gkg_raw'), 'COMPUTER') > 0) |
#     (instr(col('gkg_raw'), 'MOBILE') > 0)
# )

from pyspark.sql.functions import instr

tech_stream = gkg_stream.filter(
    (instr(col('V2Themes'), 'TECHNOLOGY') > 0) |
    (instr(col('V2Themes'), 'SCIENCE_TECHNOLOGY') > 0) |
    (instr(col('V2Themes'), 'INTERNET') > 0) |
    (instr(col('V2Themes'), 'MOBILE') > 0) |
    (instr(col('V2Themes'), 'COMPUTER') > 0)
)

# If you want to skip filtering for now, just do:
##### We might not need the NLP piece 
# tech_stream = gkg_stream

# %% [markdown]
# # Step 4: rule-based sentiment (NLP placeholder)

# %%
# sentiment_stream = tech_stream.withColumn(
#     'sentiment',
#     when(lower(col('gkg_raw')).contains('crisis'), 'negative')
#     .when(lower(col('gkg_raw')).contains('breach'), 'negative')
#     .when(lower(col('gkg_raw')).contains('scandal'), 'negative')
#     .when(lower(col('gkg_raw')).contains('lawsuit'), 'negative')
#     .when(lower(col('gkg_raw')).contains('growth'), 'positive')
#     .when(lower(col('gkg_raw')).contains('innovation'), 'positive')
#     .when(lower(col('gkg_raw')).contains('record profits'), 'positive')
#     .otherwise('neutral')
# )

# sentiment_stream.printSchema()

sentiment_stream = tech_stream.withColumn(
    'sentiment',
    when(lower(col('V2Themes')).contains('crisis'), 'negative')
    .when(lower(col('V2Themes')).contains('breach'), 'negative')
    .when(lower(col('V2Themes')).contains('scandal'), 'negative')
    .when(lower(col('V2Themes')).contains('growth'), 'positive')
    .when(lower(col('V2Themes')).contains('innovation'), 'positive')
    .otherwise('neutral')
)

# %% [markdown]
# # Step 5: Streaming sink

# %%
query = sentiment_stream.writeStream \
    .format('parquet') \
    .option('path', output_dir) \
    .option('checkpointLocation', checkpoint_dir) \
    .outputMode('append') \
    .start()

print('Streaming query started. ID:', query.id)
# Out:
# Streaming query started. ID: 75c3745e-e29c-4460-a38f-f24a1f97439c

# %%
results = spark.read.parquet(output_dir)
results.printSchema()

# results.select('DATE', 'V2Themes', 'V2Locations', 'sentiment').show(5, truncate=False)
# Out:
# root
#  |-- GKGRECORDID: string (nullable = true)
#  |-- DATE: string (nullable = true)
#  |-- SourceCollectionIdentifier: string (nullable = true)
#  |-- SourceCommonName: string (nullable = true)
#  |-- DocumentIdentifier: string (nullable = true)
#  |-- V1Counts: string (nullable = true)
#  |-- V2Counts: string (nullable = true)
#  |-- V1Themes: string (nullable = true)
#  |-- V2Themes: string (nullable = true)
#  |-- V1Locations: string (nullable = true)
#  |-- V2Locations: string (nullable = true)
#  |-- V1Persons: string (nullable = true)
#  |-- V2Persons: string (nullable = true)
#  |-- V1Organizations: string (nullable = true)
#  |-- V2Organizations: string (nullable = true)
#  |-- V1Tone: string (nullable = true)
#  |-- V2Tone: string (nullable = true)
#  |-- Dates: string (nullable = true)
#  |-- GCAM: string (nullable = true)
#  |-- SharingImage: string (nullable = true)
#  |-- RelatedImages: string (nullable = true)
#  |-- SocialImageEmbeds: string (nullable = true)
#  |-- SocialVideoEmbeds: string (nullable = true)
#  |-- Quotations: string (nullable = true)
#  |-- AllNames: string (nullable = true)
#  |-- Amounts: string (nullable = true)
#  |-- TranslationInfo: string (nullable = true)
#  |-- Extras: string (nullable = true)
#  |-- sentiment: string (nullable = false)

# %% [markdown]
# # Step 6: inspect parquet files

# %%
results = spark.read.parquet(output_dir)
results.createOrReplaceTempView('gdelt_tech_sentiment')

spark.sql('''
    SELECT sentiment, COUNT(*) AS cnt
    FROM gdelt_tech_sentiment
    GROUP BY sentiment
    ORDER BY cnt DESC
''').show(10, truncate=False)
# Out:
# +---------+----+
# |sentiment|cnt |
# +---------+----+
# |negative |9782|
# |positive |5586|
# |neutral  |2150|
# +---------+----+

# %%
output_dir
# Out:
# 'C:\\Users\\jonat\\Documents\\UMBC\\FALL_2025\\Final_Project_UMBC_BIG_DATA\\DATA\\stream_out'

# %%
results = spark.read.parquet(output_dir)
results.createOrReplaceTempView('gdelt_tech_sentiment')

spark.sql('''
    SELECT *
    FROM gdelt_tech_sentiment
''').show(10, truncate=False)
# Out:
# +-------------------+--------------+--------------------------+------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+---------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |GKGRECORDID        |DATE          |SourceCollectionIdentifier|SourceCommonName        |DocumentIdentifier                                                                                                                                           |V1Counts                                      |V2Counts                                           |V1Themes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |V2Themes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# +-------------------+--------------+--------------------------+------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+---------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |20180501153000-2892|20180501153000|1                         |prnewswire.com          |https://www.prnewswire.com/news-releases/2018-film-in-california-conference-to-celebrate-robust-in-state-production-300639884.html                           |NULL                                          |NULL                                               |TAX_FNCACT;TAX_FNCACT_EXECUTIVE;TAX_FNCACT_PRODUCER;TAX_FNCACT_AUTHOR;EPU_ECONOMY_HISTORIC;WB_678_DIGITAL_GOVERNMENT;WB_694_BROADCAST_AND_MEDIA;WB_133_INFORMATION_AND_COMMUNICATION_TECHNOLOGIES;WB_471_ECONOMIC_GROWTH;WB_1100_SUSTAINABLE_GROWTH;MEDIA_MSM;ECON_TAXATION;USPEC_POLICY1;EPU_POLICY;EPU_POLICY_TAX;EPU_CATS_TAXES;WB_1921_PRIVATE_SECTOR_DEVELOPMENT;WB_382_TAX_CREDITS_AND_DIRECT_SUBSIDIES;WB_376_INNOVATION_TECHNOLOGY_AND_ENTREPRENEURSHIP;WB_377_FIRM_INNOVATION_PRODUCTIVITY_AND_GROWTH;WB_380_FUNDING_INNOVATION;TAX_FNCACT_ACTOR;TAX_ETHNICITY;TAX_ETHNICITY_AMERICAN;SOC_GENERALCRIME;EPU_CATS_MIGRATION_FEAR_FEAR;TAX_FNCACT_MODERATOR;TAX_FNCACT_WOMEN;TAX_FNCACT_REPORTER;TAX_FNCACT_AGENT;TAX_FNCACT_SPECIAL_AGENT;TAX_FNCACT_CHAMPION;WB_2670_JOBS;WB_1467_EDUCATION_FOR_ALL;WB_470_EDUCATION;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET;TAX_FNCACT_DIRECTORS;TAX_FNCACT_MANAGERS;TAX_FNCACT_EXECUTIVES;USPEC_UNCERTAINTY1;URBAN;RURAL;UNGP_FORESTS_RIVERS_OCEANS;EDUCATION;SOC_POINTSOFINTEREST;SOC_POINTSOFINTEREST_UNIVERSITY;TAX_WORLDLANGUAGES;TAX_WORLDLANGUAGES_DEUTSCH;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
T11_UPDATESSYMPATHY;TAX_MILITARY_TITLE;TAX_MILITARY_TITLE_OFFICER;TAX_FNCACT_OFFICER;TAX_FNCACT_WOMEN;REFUGEES;EPU_CATS_MIGRATION_FEAR_MIGRATION;TERROR;REBELS;WB_2451_REBELS_GUERRILLAS_AND_INSURGENTS;WB_2445_NON_STATE_SECURITY_ACTORS;KILL;CRISISLEX_T03_DEAD;TAX_FNCACT_PROFESSOR;EPU_POLICY_WHITE_HOUSE;TAX_ETHNICITY_UKRAINIAN;TAX_WORLDLANGUAGES_UKRAINIAN;CRISISLEX_CRISISLEXREC;TAX_FNCACT_AGENTS;WB_2024_ANTI_CORRUPTION_AUTHORITIES;WB_696_PUBLIC_SECTOR_MANAGEMENT;WB_840_JUSTICE;WB_2025_INVESTIGATION;WB_831_GOVERNANCE;WB_832_ANTI_CORRUPTION;WB_1014_CRIMINAL_JUSTICE;TAX_ETHNICITY_GERMAN;TAX_WORLDLANGUAGES_GERMAN;TAX_WORLDMAMMALS;TAX_WORLDMAMMALS_HUMANS;WB_1467_EDUCATION_FOR_ALL;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET;UNGP_PHONE_INTERNET_ACCESS_COST;TAX_WORLDLANGUAGES_RUSSIA;LEADER;TAX_FNCACT_PRESIDENT;USPEC_POLITICS_GENERAL1;WB_137_WATER;WB_988_LEVEES;WB_141_WATER_RESOURCES_MANAGEMENT;WB_1000_WATER_MANAGEMENT_STRUCTURES;UNGP_FORESTS_RIVERS_OCEANS;TAX_FNCACT_VOLUNTEER;WB_2946_OPEN_SOURCE;WB_667_ICT_INFRASTRUCTURE;WB_669_SOFTWARE_INFRASTRUCTURE;WB_652_ICT_APPLICATIONS;WB_662_SOCIAL_MEDIA;WB_658_ENTERPRISE_APPLICATIONS;DRUG_TRADE;WB_1331_HEALTH_TECHNOLOGIES;WB_2453_ORGANIZED_CRIME;WB_1350_PHARMACEUTICALS;WB_621_HEALTH_NUTRITION_AND_POPULATION;WB_2456_DRUGS_AND_NARCOTICS;CRIME_CARTELS;TAX_FNCACT_PRACTITIONER;TAX_FNCACT_CITIZEN;IDEOLOGY;TAX_FNCACT_WORKER;TAX_FNCACT_OFFICIAL;|TERROR,3825;REBELS,3825;WB_2451_REBELS_GUERRILLAS_AND_INSURGENTS,3825;WB_2445_NON_STATE_SECURITY_ACTORS,3825;WB_2433_CONFLICT_AND_VIOLENCE,2028;WB_2433_CONFLICT_AND_VIOLENCE,9261;WB_2432_FRAGILITY_CONFLICT_AND_VIOLENCE,2028;WB_2432_FRAGILITY_CONFLICT_AND_VIOLENCE,9261;MEDIA_SOCIAL,283;MEDIA_SOCIAL,1615;ARMEDCONFLICT,165;ARMEDCONFLICT,5392;EPU_CATS_NATIONAL_SECURITY,165;EPU_CATS_NATIONAL_SECURITY,5392;UNGP_FORESTS_RIVERS_OCEANS,8019;TAX_FNCACT_WORKER,12719;TAX_FNCACT_CITIZEN,10926;TAX_ETHNICITY_UKRAINIAN,4892;TAX_ETHNICITY_UKRAINIAN,4979;TAX_ETHNICITY_UKRAINIAN,5097;TAX_ETHNICITY_UKRAINIAN,5265;TAX_WORLDLANGUAGES_UK
HISTORIC,2248;EPU_ECONOMY_HISTORIC,2411;EPU_ECONOMY_HISTORIC,2882;EPU_ECONOMY_HISTORIC,3407;WB_476_GREEN_GROWTH,1202;WB_471_ECONOMIC_GROWTH,1202;WB_1100_SUSTAINABLE_GROWTH,1202;TAX_WORLDLANGUAGES_BAIN,4;TAX_WORLDLANGUAGES_BAIN,224;TAX_WORLDLANGUAGES_BAIN,456;TAX_WORLDLANGUAGES_BAIN,70 ...
# |20180501153000-55  |20180501153000|1                         |cityam.com              |http://www.cityam.com/285036/aprils-top-and-bottom-performing-funds                                                                                          |NULL                                          |NULL                                               |WB_334_EQUITY_MARKETS;WB_1920_FINANCIAL_SECTOR_DEVELOPMENT;WB_332_CAPITAL_MARKETS;WB_1918_SECURITIES_MARKETS;UNGP_FORESTS_RIVERS_OCEANS;WB_698_TRADE;ARMEDCONFLICT;EPU_CATS_NATIONAL_SECURITY;ECON_TRADE_DISPUTE;TAX_FNCACT;TAX_FNCACT_INVESTOR;CRISISLEX_CRISISLEXREC;TAX_FNCACT_ANALYST;USPEC_POLICY1;EPU_UNCERTAINTY;GENERAL_GOVERNMENT;EPU_POLICY;EPU_POLICY_GOVERNMENT;TAX_FNCACT_SECRETARY;WB_696_PUBLIC_SECTOR_MANAGEMENT;WB_713_PUBLIC_FINANCE;WB_1045_TREASURY;SOC_TECHNOLOGYSECTOR;MEDIA_SOCIAL;SCANDAL;TAX_ECON_PRICE;LEADER;TAX_FNCACT_GOVERNOR;EPU_CATS_MONETARY_POLICY;ECON_INTEREST_RATES;EPU_POLICY_INTEREST_RATE;ECON_WORLDCURRENCIES;ECON_WORLDCURRENCIES_EURO;ECON_CENTRALBANK;WB_1235_CENTRAL_BANKS;WB_318_FINANCIAL_ARCHITECTURE_AND_BANKING;WB_1234_BANKING_INSTITUTIONS;EPU_POLICY_CENTRAL_BANK;EPU_POLICY_INTEREST_RATES;ECON_WORLDCURRENCIES_DOLLAR;ECON_WORLDCURRENCIES_US_DOLLAR;ECON_EMERGINGECON;EPU_ECONOMY;EPU_ECONOMY_HISTORIC;ECON_STOCKMARKET;ENV_OIL;ECON_OILPRICE;SLFID_NATURAL_RESOURCES;WB_471_ECONOMIC_GROWTH;WB_1078_DETERMINANTS_OF_GROWTH;WB_1079_COMMODITIES_AND_RESOURCES;SANCTIONS;TAX_ETHNICITY;TAX_ETHNICITY_RUSSIAN;TAX_WORLDLANGUAGES;TAX_WORLDLANGUAGES_RUSSIAN;WB_1614_NUTRITIONAL_PROGRAMS;WB_1609_FOOD_AND_IN_KIND_TRANSFERS;WB_1616_SUPPLEMENTARY;WB_1466_SOCIAL_ASSISTANCE;WB_697_SOCIAL_PROTECTION_AND_LABOR;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |CRISISLEX_CRISISLEXREC,437;ARMEDCONFLICT,312;EPU_CATS_NATIONAL_SECURITY,312;ECON_CENTRALBANK,2213;ECON_CENTRALBANK,4531;WB_1235_CENTRAL_BANKS,2213;WB_1235_CENTRAL_BANKS,4531;WB_318_FINANCIAL_ARCHITECTURE_AND_BANKING,2213;WB_318_FINANCIAL_ARCHITECTURE_AND_BANKING,4531;WB_1234_BANKING_INSTITUTIONS,2213;WB_1234_BANKING_INSTITUTIONS,4531;EPU_POLICY_CENTRAL_BANK,2213;EPU_POLICY_CENTRAL_BANK,4531;WB_334_EQUITY_MARKETS,58;WB_334_EQUITY_MARKETS,178;WB_1920_FINANCIAL_SECTOR_DEVELOPMENT,58;WB_1920_FINANCIAL_SECTOR_DEVELOPMENT,178;WB_332_CAPITAL_MARKETS,58;WB_332_CAPITAL_MARKETS,178;WB_1918_SECURITIES_MARKETS,58;WB_1918_SECURITIES_MARKETS,178;ECON_OILPRICE,3111;ECON_OILPRICE,3516;SCANDAL,1184;SLFID_NATURAL_RESOURCES,3417;WB_471_ECONOMIC_GROWTH,3417;WB_1078_DETERMINANTS_OF_GROWTH,3417;WB_1079_COMMODITIES_AND_RESOURCES,3417;WB_696_PUBLIC_SECTOR_MANAGEMENT,876;WB_696_PUBLIC_SECTOR_MANAGEMENT,2717;WB_713_PUBLIC_FINANCE,876;WB_713_PUBLIC_FINANCE,2717;WB_1045_TREASURY,876;WB_1045_TREASURY,2717;SOC_TECHNOLOGYSECTOR,1031;TAX_ECON_PRICE,1700;TAX_ECON_PRICE,2865;TAX_ECON_PRICE,3347;USPEC_POLICY1,693;EPU_UNCERTAINTY,693;ECON_STOCKMARKET,2670;UNGP_FORESTS_RIVERS_OCEANS,103;UNGP_FORESTS_RIVERS_OCEANS,3417;WB_1614_NUTRITIONAL_PROGRAMS,4327;WB_1609_FOOD_AND_IN_KIND_TRANSFERS,4327;WB_1616_SUPPLEMENTARY,4327;WB_1466_SOCIAL_ASSISTANCE,4327;WB_697_SOCIAL_PROTECT ...
# |20180501153000-64  |20180501153000|1                         |mondaq.com              |http://mondaq.com/unitedstates/x/697446/Patent/httpwwwfoglerscomeventsandresourcespublications                                                               |NULL                                          |NULL                                               |SOC_INNOVATION;GENERAL_HEALTH;MEDICAL;WB_1331_HEALTH_TECHNOLOGIES;WB_1350_PHARMACEUTICALS;WB_621_HEALTH_NUTRITION_AND_POPULATION;CRISISLEX_CRISISLEXREC;LEGISLATION;EPU_POLICY;EPU_POLICY_LAW;CRISISLEX_C03_WELLBEING_HEALTH;WB_1614_NUTRITIONAL_PROGRAMS;WB_1609_FOOD_AND_IN_KIND_TRANSFERS;WB_1615_THERAPEUTIC;WB_1466_SOCIAL_ASSISTANCE;WB_697_SOCIAL_PROTECTION_AND_LABOR;TAX_FNCACT;TAX_FNCACT_AGENT;TAX_FNCACT_ACTOR;TAX_FNCACT_DOCTOR;TAX_FNCACT_PHYSICIAN;WB_2453_ORGANIZED_CRIME;WB_2433_CONFLICT_AND_VIOLENCE;WB_2432_FRAGILITY_CONFLICT_AND_VIOLENCE;WB_2456_DRUGS_AND_NARCOTICS;WB_1921_PRIVATE_SECTOR_DEVELOPMENT;WB_346_COMPETITIVE_INDUSTRIES;WB_818_INDUSTRY_POLICY_AND_REAL_SECTORS;WB_1281_MANUFACTURING;WB_845_LEGAL_AND_REGULATORY_FRAMEWORK;WB_696_PUBLIC_SECTOR_MANAGEMENT;WB_851_INTELLECTUAL_P
WB_133_INFORMATION_AND_COMMUNICATION_TECHNOLOGIES,10997;TAX_FNCACT_PRACTITIONERS,6357;EPU_POLICY_REGULATORY,7467;EPU_POLICY_REGULATORY,7637;TAX_FNCACT_PHYSICIAN,1757;TAX_FNCACT_AUTHOR,12720;TAX_FNCACT_AUTHOR,13067;EPU_ECONOMY_HISTORIC,14796;DISABILITY,14435;CRISISLEX_CRISISLEXREC,410;CRISISLEX_CRISISLEXREC,3676;TAX_FNCACT_DOCTORS,3639;TAX_FNCACT_DOCTORS,3718;WB ...
# |20180501153000-69  |20180501153000|1                         |rabble.ca               |http://rabble.ca/columnists/2018/05/canada-sets-feminist-agenda-2018-g7-summit                                                                               |NULL                                          |NULL                                               |TAX_FNCACT;TAX_FNCACT_FEMINIST;LEADER;TAX_FNCACT_PRESIDENT;USPEC_POLITICS_GENERAL1;TAX_FNCACT_MINISTER;TAX_FNCACT_PRIME_MINISTER;GENERAL_GOVERNMENT;EPU_POLICY;EPU_POLICY_GOVERNMENT;ELECTION;TAX_FNCACT_WOMEN;KILL;TAX_ECON_FREETRADEAGREEMENTS;TAX_ECON_FREETRADEAGREEMENTS_NAFTA;EPU_ECONOMY_HISTORIC;TAX_ETHNICITY;TAX_ETHNICITY_AMERICAN;TAX_FNCACT_LEADERS;TAX_ETHNICITY_CANADIAN;WB_698_TRADE;UNGP_FORESTS_RIVERS_OCEANS;SOC_EXPRESSSUPPORT;CRISISLEX_T04_INFRASTRUCTURE;USPEC_POLICY1;EPU_ECONOMY;AGRICULTURE;CRISISLEX_C07_SAFETY;FOOD_SECURITY;WB_199_FOOD_SECURITY;WB_435_AGRICULTURE_AND_FOOD_SECURITY;WB_1967_AGRICULTURAL_RISK_AND_SECURITY;UNGP_AFFORDABLE_NUTRITIOUS_FOOD;TAX_ETHNICITY_CANADIANS;EPU_POLICY_POLICY;CRISISLEX_T03_DEAD;WB_1921_PRIVATE_SECTOR_DEVELOPMENT;WB_376_INNOVATION_TECHNOLOGY_AND_ENTREPRENEURSHIP;WB_1917_INTELLECTUAL_PROPERTY;WB_377_FIRM_INNOVATION_PRODUCTIVITY_AND_GROWTH;PROPERTY_RIGHTS;WB_845_LEGAL_AND_REGULATORY_FRAMEWORK;WB_696_PUBLIC_SECTOR_MANAGEMENT;WB_1907_PERSONAL_PROPERTY_RIGHTS;WB_1039_PROPERTY_LAWS_AND_REGULATIONS;WB_851_INTELLECTUAL_PROPERTY_RIGHTS;TAX_FNCACT_MINISTERS;TAX_FNCACT_FOREIGN_MINISTER;NEGOTIATIONS;WB_840_JUSTICE;WB_2473_DIPLOMACY_AND_NEGOTIATIONS;WB_939_NEGOTIATION;WB_2470_PEACE_OPERATIONS_AND_CONFLICT_MANAGEMENT;WB_936_ALTERNATIVE_DISPUTE_RESOLUTION;WB_2432_FRAGILITY_CONFLICT_AND_VIOLENCE;WB_843_DISPUTE_RESOLUTION;WB_2471_PEACEKEEPING;TAX_FNCACT_REPRESENTATIVE;EPU_POLICY_CONGRESS;MANMADE_DISASTER_IMPLIED;TAX_ETHNICITY_CHINESE;TAX_WORLDLANGUAGES;TAX_WORLDLANGUAGES_CHINESE;WB_615_GENDER;MOVEMENT_WOMENS;WB_919_GENDER_AND_HUMAN_DEVELOPMENT;UNGP_GENDER_EQUALITY;TAX_FNCACT_NOBLE;EXTREMISM;TAX_FNCACT_AMBASSADOR;TAX_DISEASE;TAX_DISEASE_FEMINIZATION;TAX_FNCACT_FEMINISTS;MEDIA_MSM;WB_678_DIGITAL_GOVERNMENT;WB_694_BROADCAST_AND_MEDIA;WB_133_INFORMATION_AND_COMMUNICATION_TECHNOLOGIES;EPU_POLICY_BUDGET;TAX_FNCACT_INVESTOR;ECON_ENTREPRENEURSHIP;TAX_FNCACT_SUPPORTERS;ECON_WORLDCURRENCIES;ECON_WORLDCURRENCIES_DOLLARS;                                                                                                                                                                                                                                                                                                                                               |MOVEMENT_WOMENS,3832;MOVEMENT_WOMENS,3948;MOVEMENT_WOMENS,4433;MOVEMENT_WOMENS,5365;WB_919_GENDER_AND_HUMAN_DEVELOPMENT,3832;WB_919_GENDER_AND_HUMAN_DEVELOPMENT,3948;WB_919_GENDER_AND_HUMAN_DEVELOPMENT,4433;WB_919_GENDER_AND_HUMAN_DEVELOPMENT,5365;UNGP_GENDER_EQUALITY,3832;UNGP_GENDER_EQUALITY,3948;UNGP_GENDER_EQUALITY,4433;UNGP_GENDER_EQUALITY,5365;TAX_FNCACT_FEMINISTS,5129;WB_1921_PRIVATE_SECTOR_DEVELOPMENT,2144;WB_376_INNOVATION_TECHNOLOGY_AND_ENTREPRENEURSHIP,2144;WB_1917_INTELLECTUAL_PROPERTY,2144;WB_377_FIRM_INNOVATION_PRODUCTIVITY_AND_GROWTH,2144;TAX_FNCACT_LEADERS,1068;TAX_FNCACT_LEADERS,4375;TAX_FNCACT_PRIME_MINISTER,285;TAX_FNCACT_PRIME_MINISTER,1527;TAX_FNCACT_PRIME_MINISTER,4692;TAX_FNCACT_PRIME_MINISTER,5091;CRISISLEX_T03_DEAD,2092;PROPERTY_RIGHTS,2151;WB_845_LEGAL_AND_REGULATORY_FRAMEWORK,2151;WB_696_PUBLIC_SECTOR_MANAGEMENT,2151;WB_1907_PERSONAL_PROPERTY_RIGHTS,2151;WB_1039_PROPERTY_LAWS_AND_REGULATIONS,2151;CRISISLEX_C07_SAFETY,1987;TAX_FNCACT_AMBASSADOR,4621;EPU_POLICY_CONGRESS,1666;EPU_POLICY_CONGRESS,3316;TAX_ETHNICITY_AMERICAN,1052;TAX_ETHNICITY_AMERICAN,4570;TAX_FNCACT_SUPPORTERS,5956;ECON_WORLDCURRENCIES_DOLLARS,6096;TAX_FNCACT_FOREIGN_MINISTER,2406;CRISISLEX_T04_INFRASTRUCTURE,1683;EPU_ECONOMY_HISTORIC,833;FOOD_SECURITY,1987;WB_199_FOOD_SECURITY,1987;WB_435_AGRICULTURE_AND_FOOD_SECURITY,1987;WB_1967_AGRICULTUR ...
# |20180501153000-99  |20180501153000|1                         |cuinsight.com           |https://www.cuinsight.com/partnering-to-accelerate-financial-literacy.html                                                                                   |NULL                                          |NULL                                               |UNGP_EDUCATION;WB_1467_EDUCATION_FOR_ALL;WB_470_EDUCATION;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET;UNGP_FORESTS_RIVERS_OCEANS;EPU_ECONOMY;EPU_ECONOMY_HISTORIC;EDUCATION;SOC_POINTSOFINTEREST;SOC_POINTSOFINTEREST_SCHOOL;SOC_POINTSOFINTEREST_HIGH_SCHOOL;TAX_FNCACT;TAX_FNCACT_STUDENTS;ECON_DEBT;WB_1104_MACROECONOMIC_VULNERABILITY_AND_DEBT;WB_450_DEBT;USPEC_POLICY1;EPU_POLICY;EPU_POLICY_SPENDING;WB_678_DIGITAL_GOVERNMENT;WB_652_ICT_APPLICATIONS;WB_2363_MOBILE_APPLICATIONS;WB_658_ENTERPRISE_APPLICATIONS;WB_133_INFORMATION_AND_COMMUNICATION_TECHNOLOGIES;EPU_POLICY_POLICYMAKERS;ECON_CENTRALBANK;WB_1235_CENTRAL_BANKS;WB_318_FINANCIAL_ARCHITECTURE_AND_BANKING;WB_1920_FINANCIAL_SECTOR_DEVELOPMENT;WB_1234_BANKING_INSTITUTIONS;WB_363_FINANCIAL_INCLUSION;WB_364_CONSUMER_PROTECTION;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |ECON_CENTRALBANK,1208;WB_1235_CENTRAL_BANKS,1208;WB_318_FINANCIAL_ARCHITECTURE_AND_BANKING,1208;WB_1920_FINANCIAL_SECTOR_DEVELOPMENT,1208;WB_1234_BANKING_INSTITUTIONS,1208;WB_678_DIGITAL_GOVERNMENT,841;WB_652_ICT_APPLICATIONS,841;WB_2363_MOBILE_APPLICATIONS,841;WB_658_ENTERPRISE_APPLICATIONS,841;WB_133_INFORMATION_AND_COMMUNICATION_TECHNOLOGIES,841;WB_1467_EDUCATION_FOR_ALL,32;WB_1467_EDUCATION_FOR_ALL,348;WB_1467_EDUCATION_FOR_ALL,890;WB_470_EDUCATION,32;WB_470_EDUCATION,348;WB_470_EDUCATION,890;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS,32;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS,348;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS,890;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET,32;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET,348;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET,890;UNGP_FORESTS_RIVERS_OCEANS,45;UNGP_EDUCATION,25;UNGP_EDUCATION,341;UNGP_EDUCATION,1013;UNGP_EDUCATION,1357;SOC_POINTSOFINTEREST_SCHOOL,279;EDUCATION,131;EDUCATION,211;EDUCATION,618;WB_363_FINANCIAL_INCLUSION,1268;WB_364_CONSUMER_PROTECTION,1268;USPEC_POLICY1,770;EPU_POLICY_SPENDING,770;EPU_ECONOMY,121;EPU_ECONOMY_HISTORIC,121;TAX_FNCACT_STUDENTS,288;SOC_POINTSOFINTEREST_HIGH_SCHOOL,279;ECON_DEBT,447;WB_1104_MACROECONOMIC_VULNERABILITY_AND_DEBT,447;WB_450_DEBT,447;EPU_POLICY_POLICYMAKERS,1179;                                                          ...
# |20180501153000-126 |20180501153000|1                         |thesouthern.com         |http://thesouthern.com/news/national/how-the-proposed-sprint-and-t-mobile-b-deal-might/article_134ff7ae-ddcd-5e89-9cd6-62ffef7ef20c.html                     |NULL                                          |NULL                                               |RURAL;TAX_ECON_PRICE;UNGP_PHONE_INTERNET_ACCESS_COST;EPU_ECONOMY_HISTORIC;AFFECT;TAX_FNCACT;TAX_FNCACT_LEADERS;EPU_CATS_MIGRATION_FEAR_FEAR;WB_696_PUBLIC_SECTOR_MANAGEMENT;WB_2048_COMPENSATION_CAREERS_AND_INCENTIVES;WB_723_PUBLIC_ADMINISTRATION;WB_724_HUMAN_RESOURCES_FOR_PUBLIC_SECTOR;SOC_INNOVATION;TAX_WORLDLANGUAGES;TAX_WORLDLANGUAGES_BERIN;LEADER;TAX_FNCACT_PRESIDENT;USPEC_POLITICS_GENERAL1;TAX_FNCACT_CEO;WB_678_DIGITAL_GOVERNMENT;WB_2943_SWITCHES;WB_667_ICT_INFRASTRUCTURE;WB_672_NETWORK_MANAGEMENT;WB_133_INFORMATION_AND_COMMUNICATION_TECHNOLOGIES;TAX_FNCACT_ANALYSTS;TAX_FNCACT_ANALYST;WB_2670_JOBS;WB_1467_EDUCATION_FOR_ALL;WB_470_EDUCATION;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET;UNGP_JOB_OPPORTUNITIES_EMPLOYMENT;TAX_FNCACT_REGULATORS;GENERAL_GOVERNMENT;EPU_POLICY;EPU_POLICY_CONGRESS;WB_840_JUSTICE;WB_1921_PRIVATE_SECTOR_DEVELOPMENT;WB_406_COMPETITION_POLICY;WB_2101_ANTITRUST;EPU_CATS_REGULATION;EPU_POLICY_REGULATORY;UNGP_FORESTS_RIVERS_OCEANS;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |WB_696_PUBLIC_SECTOR_MANAGEMENT,957;WB_2048_COMPENSATION_CAREERS_AND_INCENTIVES,957;WB_723_PUBLIC_ADMINISTRATION,957;WB_724_HUMAN_RESOURCES_FOR_PUBLIC_SECTOR,957;RURAL,146;RURAL,3112;RURAL,3218;RURAL,3348;RURAL,3478;RURAL,3606;SOC_INNOVATION,976;WB_1921_PRIVATE_SECTOR_DEVELOPMENT,4061;WB_406_COMPETITION_POLICY,4061;WB_2101_ANTITRUST,4061;EPU_CATS_REGULATION,4061;WB_840_JUSTICE,4030;UNGP_PHONE_INTERNET_ACCESS_COST,336;TAX_FNCACT_LEADERS,662;EPU_ECONOMY_HISTORIC,506;EPU_ECONOMY_HISTORIC,699;EPU_ECONOMY_HISTORIC,1138;EPU_ECONOMY_HISTORIC,1311;AFFECT,555;TAX_WORLDLANGUAGES_BERIN,1536;TAX_ECON_PRICE,336;GENERAL_GOVERNMENT,3811;EPU_POLICY_CONGRESS,3811;WB_2670_JOBS,3139;WB_1467_EDUCATION_FOR_ALL,3139;WB_470_EDUCATION,3139;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS,3139;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET,3139;EPU_POLICY_REGULATORY,4338;EPU_POLICY_REGULATORY,4402;TAX_FNCACT_ANALYST,1986;TAX_FNCACT_ANALYST,4196;TAX_FNCACT_REGULATORS,3661;TAX_FNCACT_CEO,1720;UNGP_FORESTS_RIVERS_OCEANS,4712;LEADER,1554;TAX_FNCACT_PRESIDENT,1554;USPEC_POLITICS_GENERAL1,1554;UNGP_JOB_OPPORTUNITIES_EMPLOYMENT,3139;EPU_CATS_MIGRATION_FEAR_FEAR,890;WB_678_DIGITAL_GOVERNMENT,1752;WB_2943_SWITCHES,1752;WB_667_ICT_INFRASTRUCTURE,1752;WB_672_NETWORK_MANAGEMENT,1752;WB_133_INFORMATION_AND_COMMUNICATION_TECHNOLOGIES,1752;TAX_FNCACT_ANALYSTS,1863;TAX_FNCACT_ ...
# |20180501153000-147 |20180501153000|1                         |ilkestonadvertiser.co.uk|https://www.ilkestonadvertiser.co.uk/news/business/rbs-to-close-162-branches-and-792-jobs-1-9144330                                                          |NULL                                          |NULL                                               |WB_2670_JOBS;WB_1467_EDUCATION_FOR_ALL;WB_470_EDUCATION;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET;TAX_FNCACT;TAX_FNCACT_SPOKESPERSON;AFFECT;WB_318_FINANCIAL_ARCHITECTURE_AND_BANKING;WB_1920_FINANCIAL_SECTOR_DEVELOPMENT;WB_1234_BANKING_INSTITUTIONS;WB_1236_COMMERCIAL_BANKING;EPU_ECONOMY_HISTORIC;WB_1252_MOBILE_BANKING;WB_371_BRANCHLESS_BANKING;WB_363_FINANCIAL_INCLUSION;TAX_FNCACT_SPECIALIST;CRISISLEX_T11_UPDATESSYMPATHY;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |AFFECT,398;AFFECT,1516;WB_1252_MOBILE_BANKING,1403;WB_1252_MOBILE_BANKING,2296;WB_371_BRANCHLESS_BANKING,1403;WB_371_BRANCHLESS_BANKING,2296;WB_363_FINANCIAL_INCLUSION,1403;WB_363_FINANCIAL_INCLUSION,2296;WB_318_FINANCIAL_ARCHITECTURE_AND_BANKING,535;WB_1920_FINANCIAL_SECTOR_DEVELOPMENT,535;WB_1234_BANKING_INSTITUTIONS,535;WB_1236_COMMERCIAL_BANKING,535;EPU_ECONOMY_HISTORIC,544;EPU_ECONOMY_HISTORIC,1848;CRISISLEX_T11_UPDATESSYMPATHY,2399;TAX_FNCACT_SPOKESPERSON,279;TAX_FNCACT_SPOKESPERSON,704;TAX_FNCACT_SPECIALIST,2339;WB_2670_JOBS,36;WB_2670_JOBS,203;WB_1467_EDUCATION_FOR_ALL,36;WB_1467_EDUCATION_FOR_ALL,203;WB_470_EDUCATION,36;WB_470_EDUCATION,203;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS,36;WB_2131_EMPLOYABILITY_SKILLS_AND_JOBS,203;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET,36;WB_1484_EDUCATION_SKILLS_DEVELOPMENT_AND_LABOR_MARKET,203;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# +-------------------+--------------+--------------------------+------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+---------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 10 rows

# %%
# quick visuals in jupyter
import pandas as pd

df_sent = spark.sql('''
    SELECT sentiment, COUNT(*) AS cnt
    FROM gdelt_tech_sentiment
    GROUP BY sentiment
''').toPandas()

df_sent
# Out:
#   sentiment   cnt
# 0  positive  5586
# 1   neutral  2150
# 2  negative  9782

# %%
import matplotlib.pyplot as plt

plt.bar(df_sent['sentiment'], df_sent['cnt'])
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment distribution for tech-related May 2018 GDELT records')
plt.show()

# %% [markdown]
# # Step 7: Cooler graphs

# %%
# Spark SQL to get numbers 

pair_counts = spark.sql('''
SELECT sentiment,
       SUM(CASE WHEN lower(V2Themes) LIKE '%crisis%' THEN 1 ELSE 0 END) AS crisis,
       SUM(CASE WHEN lower(V2Themes) LIKE '%breach%' THEN 1 ELSE 0 END) AS breach,
       SUM(CASE WHEN lower(V2Themes) LIKE '%growth%' THEN 1 ELSE 0 END) AS growth,
       SUM(CASE WHEN lower(V2Themes) LIKE '%innovation%' THEN 1 ELSE 0 END) AS innovation
FROM gdelt_tech_sentiment
GROUP BY sentiment
''')

pair_pd = pair_counts.toPandas().set_index('sentiment')
pair_pd
# Out:
#            crisis  breach  growth  innovation
# sentiment
# positive        0       0    3868        4944
# neutral         0       0       0           0
# negative     9733       0    5798        6796

# %%
pair_pd.plot(
    kind='bar',
    figsize=(10,6),
    color=['red','orange','green','blue'],
    edgecolor='black'
)

plt.title('Buzzword Sentiment Pair Counts in Streaming GDELT Data')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.legend(title='Buzzword')
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# ## STREAMING STOP UNCOMMENT
# let the stream work for a few minutes
# I tested it, and the numbers are slowly going up
# just give spark some time

# %%
#### run this when you want the streaming query to stop
# query.stop()
